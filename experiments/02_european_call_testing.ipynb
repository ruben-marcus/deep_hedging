# %%
# %cd ..
# Out:
# /Users/rubenmarcus/Desktop/Code/Personal Projects/Deep Hedging/deep_hedging

# %%
import math
import numpy as np

from src.derivatives.european_call import (
    black_scholes_call,
    black_scholes_delta,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3
#       4 import numpy as np
#       5
# ----> 6 from src.derivatives.european_call import (
#       7     black_scholes_call,
#       8     black_scholes_delta,
#       9 )
#
# ModuleNotFoundError: No module named 'src'

# %%
S = 100.0
K = 100.0
sigma = 0.20
T = 1.0
t = 0.0
r = 0.0


price = black_scholes_call(
    S=S,
    K=K,
    sigma=sigma,
    T=T,
    t=t,
    r=r,
)

delta = black_scholes_delta(
    S=S,
    K=K,
    sigma=sigma,
    T=T,
    t=t,
    r=r,
)

print("call price:", price)
print("delta:     ", delta)
# Out:
# call price: 7.965567455405804
# delta:      0.539827837277029
